# %% [markdown]
# ### Add Simlink

# %%
$Path = /home/david/.oh-my-posh-themes/davids-november.omp.json"
$Target = "/home/david/Code/seasonal-theming/November/davids-november.omp.json"

New-Item -ItemType SymbolicLink -Path $Path -Target $Target

# %%
sudo ln -s $Target $Path
