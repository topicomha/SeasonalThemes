# %% [markdown]
# # Add Simlink

# %% [markdown]
# ### Linux
# My Linux path to all oh-my-posh themes: `/home/david/.oh-my-posh-themes/` Example Theme File:  `davids-november.omp.json`
#
# Path to repo: `/home/david/Code/seasonal-theming/[Month]/` Example Theme File: `davids-november.omp.json`

# %%
$Month = "April"
$Path = "/home/david/.oh-my-posh-themes/davids-$Month.omp.json"
$Target = "/home/david/Code/seasonal-theming/$Month/davids-$Month.omp.json"

$Month
$Path
$Target

# %%
New-Item -ItemType SymbolicLink -Path $Path -Target $Target

# %% [markdown]
# Powershell doesn't work on linux. So here is the linux script to create it.
#
# Also, I don't think powershell works with relative paths. Use absolute paths.

# %%
sudo ln -s $Target $Path

# %% [markdown]
# ### Windows
# My Windows path to oh-my-posh themes: `C:\Users\david.boyd\AppData\Local\Programs\oh-my-posh\themes\` Example Theme File:  `davids-november.omp.json`
#
# Path to repo: `C:\Users\david.boyd\code\SeasonalThemes\[Month]` Example Theme File:  `davids-november.omp.json`

# %%
$Month = "November"
$Path = "C:\Users\david.boyd\AppData\Local\Programs\oh-my-posh\themes\davids-$Month.omp.json"
$Target = "C:\Users\david.boyd\code\SeasonalThemes\$Month\davids-$Month.omp.json"

$Month 
$Path
$Target

# %%
New-Item -ItemType SymbolicLink -Path $Path -Target $Target

# %% [markdown]
# ### Test theme

# %%
oh-my-posh init pwsh --config "$env:POSH_THEMES_PATH\davids-february.omp.json" | Invoke-Expression
